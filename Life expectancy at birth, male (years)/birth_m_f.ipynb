# %% [markdown]
# Male Life Expectancy

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_total_birth_male= pd.read_excel(r"C:\Users\nxg11006\OneDrive - NXP\Desktop\Datasets\Life expectancy at birth, male (years)\API_SP.DYN.LE00.MA.IN_DS2_en_excel_v2_4191.xls", engine='xlrd')
df_total_birth_male
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2026-07-01 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 263                       Kosovo                          XKX
# 264                  Yemen, Rep.                          YEM
# 265                 South Africa                          ZAF
# 266                       Zambia                          ZMB
# 267                     Zimbabwe                          ZWE
#
#                                  Unnamed: 2         Unnamed: 3   Unnamed: 4  \
# 0                                       NaN                NaN          NaN
# ...

# %%
df_total_birth_male.shape
# Out:
# (268, 70)

# %% [markdown]
# Dropping first 2 rows - metadata

# %%
df_total_birth_male.iloc[2].tolist()[:4]
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']

# %%
temp_list1 = df_total_birth_male.iloc[2].tolist()[:4] #strings
temp_list2 = df_total_birth_male.iloc[2].tolist()[4:] #integers
temp_list2 = list(map(int, temp_list2))
temp_list1.extend(temp_list2) #creating column headers

# %%
df_total_birth_male.columns = temp_list1 #resetting default columns

# %%
df_total_birth_male = df_total_birth_male.iloc[3:].reset_index(drop=True)
df_total_birth_male
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                              Indicator Name     Indicator Code       1960  \
# 0    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  60.746000
# 1    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  42.448909
# 2    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  32.136000
# 3    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  35.925673
# ...

# %% [markdown]
# Checking columns with all null values and dropping them.

# %%
for i in df_total_birth_male.columns:
    if df_total_birth_male[i].isna().all():
        df_total_birth_male.drop(columns=i, inplace=True)

df_total_birth_male
#column of year 2025 dropped
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                              Indicator Name     Indicator Code       1960  \
# 0    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  60.746000
# 1    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  42.448909
# 2    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  32.136000
# 3    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  35.925673
# ...

# %%
len(df_total_birth_male['Country Code'].unique()) #checking if there are redundant values in the columns
# Out:
# 265

# %% [markdown]
# Combining income data with main df

# %%
df_income = pd.read_excel(r"C:\Users\nxg11006\OneDrive - NXP\Desktop\Datasets\Life expectancy at birth, male (years)\API_SP.DYN.LE00.MA.IN_DS2_en_excel_v2_4191.xls", sheet_name='Metadata - Countries',engine='xlrd')

# %%
df_income
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG  Middle East & North Africa           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 259          XKX       Europe & Central Asia  Upper middle income
# 260          YEM  Middle East & North Africa           Low income
# 261          ZAF          Sub-Saharan Africa  Upper middle income
# 262          ZMB          Sub-Saharan Africa  Lower middle income
# 263          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
len(df_income['Country Code'].unique())
# Out:
# 264

# %%
df_income.drop(columns=['SpecialNotes','TableName'], inplace=True)

# %%
df_income
# Out:
#     Country Code                      Region          IncomeGroup
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG  Middle East & North Africa           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 259          XKX       Europe & Central Asia  Upper middle income
# 260          YEM  Middle East & North Africa           Low income
# 261          ZAF          Sub-Saharan Africa  Upper middle income
# 262          ZMB          Sub-Saharan Africa  Lower middle income
# 263          ZWE          Sub-Saharan Africa  Lower middle income
#
# [264 rows x 3 columns]

# %% [markdown]
# Filling missing values with custom text for better interpretation in 'IncomeGroup' and 'Region' columns.

# %%
df_total_birth_male = pd.merge(df_total_birth_male, df_income, on='Country Code')
df_total_birth_male['IncomeGroup'] = df_total_birth_male['IncomeGroup'].fillna('Income Unavailable')
df_total_birth_male['Region'] = df_total_birth_male['Region'].fillna('Region Unavailable')
df_total_birth_male
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 259                       Kosovo          XKX
# 260                  Yemen, Rep.          YEM
# 261                 South Africa          ZAF
# 262                       Zambia          ZMB
# 263                     Zimbabwe          ZWE
#
#                              Indicator Name     Indicator Code       1960  \
# 0    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  60.746000
# 1    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  42.448909
# 2    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  32.136000
# 3    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN  35.925673
# ...

# %%
df_total_birth_male.to_csv('df_total_birth_male.csv', index=False) #saving file for dashboard usage.

# %% [markdown]
# Female Life Expectancy

# %%
df_total_birth_female= pd.read_excel(r"C:\Users\nxg11006\OneDrive - NXP\Desktop\Datasets\Life expectancy at birth, female (years)\API_SP.DYN.LE00.FE.IN_DS2_en_excel_v2_4627.xls", engine='xlrd')
df_total_birth_female
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2026-07-01 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 263                       Kosovo                          XKX
# 264                  Yemen, Rep.                          YEM
# 265                 South Africa                          ZAF
# 266                       Zambia                          ZMB
# 267                     Zimbabwe                          ZWE
#
#                                    Unnamed: 2         Unnamed: 3   Unnamed: 4  \
# 0                                         NaN                NaN          NaN
# ...

# %%
df_total_birth_female.shape
# Out:
# (268, 70)

# %% [markdown]
# Dropping first 2 rows - metadata

# %%
df_total_birth_female.iloc[2].tolist()[:4]
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']

# %%
temp_list1 = df_total_birth_female.iloc[2].tolist()[:4] #strings
temp_list2 = df_total_birth_female.iloc[2].tolist()[4:] #integers
temp_list2 = list(map(int, temp_list2))
temp_list1.extend(temp_list2) #creating column headers

# %%
df_total_birth_female.columns = temp_list1 #resetting default columns

# %%
df_total_birth_female = df_total_birth_female.iloc[3:].reset_index(drop=True)
df_total_birth_female
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                                Indicator Name     Indicator Code       1960  \
# 0    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  67.459000
# 1    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  45.998074
# 2    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  33.549000
# 3    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  39.817586
# ...

# %% [markdown]
# Checking columns with all null values and dropping them.

# %%
for i in df_total_birth_female.columns:
    if df_total_birth_female[i].isna().all():
        df_total_birth_female.drop(columns=i, inplace=True)

df_total_birth_female
#column of year 2025 dropped
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                                Indicator Name     Indicator Code       1960  \
# 0    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  67.459000
# 1    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  45.998074
# 2    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  33.549000
# 3    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  39.817586
# ...

# %%
len(df_total_birth_female['Country Code'].unique()) #checking if there are redundant values in the columns
# Out:
# 265

# %%
df_income = pd.read_excel(r"C:\Users\nxg11006\OneDrive - NXP\Desktop\Datasets\Life expectancy at birth, female (years)\API_SP.DYN.LE00.FE.IN_DS2_en_excel_v2_4627.xls", sheet_name='Metadata - Countries',engine='xlrd')

# %%
df_income
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG  Middle East & North Africa           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 259          XKX       Europe & Central Asia  Upper middle income
# 260          YEM  Middle East & North Africa           Low income
# 261          ZAF          Sub-Saharan Africa  Upper middle income
# 262          ZMB          Sub-Saharan Africa  Lower middle income
# 263          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
len(df_income['Country Code'].unique()) #checking if there are redundant values in the columns
# Out:
# 264

# %%
df_income.drop(columns=['SpecialNotes','TableName'], inplace=True)

# %%
df_income
# Out:
#     Country Code                      Region          IncomeGroup
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG  Middle East & North Africa           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 259          XKX       Europe & Central Asia  Upper middle income
# 260          YEM  Middle East & North Africa           Low income
# 261          ZAF          Sub-Saharan Africa  Upper middle income
# 262          ZMB          Sub-Saharan Africa  Lower middle income
# 263          ZWE          Sub-Saharan Africa  Lower middle income
#
# [264 rows x 3 columns]

# %% [markdown]
# Filling missing values with custom text for better interpretation in 'IncomeGroup' and 'Region' columns.

# %%
df_total_birth_female = pd.merge(df_total_birth_female, df_income, on='Country Code')
df_total_birth_female['IncomeGroup'] = df_total_birth_female['IncomeGroup'].fillna('Income Unavailable')
df_total_birth_female['Region'] = df_total_birth_female['Region'].fillna('Region Unavailable')
df_total_birth_female
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 259                       Kosovo          XKX
# 260                  Yemen, Rep.          YEM
# 261                 South Africa          ZAF
# 262                       Zambia          ZMB
# 263                     Zimbabwe          ZWE
#
#                                Indicator Name     Indicator Code       1960  \
# 0    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  67.459000
# 1    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  45.998074
# 2    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  33.549000
# 3    Life expectancy at birth, female (years)  SP.DYN.LE00.FE.IN  39.817586
# ...

# %%
df_total_birth_female.to_csv('df_total_birth_female.csv', index=False) #saving file for dashboard usage.

# %% [markdown]
# Statistical Analysis

# %% [markdown]
# Q1 : For which income group has the difference in average life expectancy of
# men and women changed the most between 1960 and 2023?

# %%
import copy
difference = copy.deepcopy(df_total_birth_male.iloc[:,0:4])
difference = pd.concat([difference,copy.deepcopy(df_total_birth_male.iloc[:,-2:])], axis=1)
difference
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 259                       Kosovo          XKX
# 260                  Yemen, Rep.          YEM
# 261                 South Africa          ZAF
# 262                       Zambia          ZMB
# 263                     Zimbabwe          ZWE
#
#                              Indicator Name     Indicator Code  \
# 0    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# 1    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# 2    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# 3    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# 4    Life expectancy at birth, male (years)  SP.DYN.LE00.MA.IN
# ...

# %%
#difference of life expectancies over the years for male and female
for i in range(1960, 2025, 1):
    difference[i] = abs(df_total_birth_male[i] - df_total_birth_female[i])

# %% [markdown]
# Result

# %%
#Grouped values based on IncomeGroup for each year
difference['Change'] = abs(difference[1960] - difference[2023])
result1 = (difference.groupby('IncomeGroup')['Change'].max())
print(f"Income Group with significant difference: {result1.idxmax()}")
result1
# Out:
# Income Group with significant difference: Lower middle income
# IncomeGroup
# High income            6.149000
# Income Unavailable     3.444099
# Low income             4.552000
# Lower middle income    7.831000
# Upper middle income    7.221000
# Name: Change, dtype: float64

# %% [markdown]
# -----------------------------------End of Notebook-----------------------------------------
